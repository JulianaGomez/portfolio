# %% [markdown]
# This notebook is split into 3 parts:
#
# 1. Add POS with SpaCY - sample data: Mock example of the POS approach, produces two lists: one with tokens, and one with POS for sample data.
#
# 2. Add POS with SpaCY - our data - 2 lists: POS approach using our Emo_DV/Arctic, produces two lists: one with tokens, and one with POS for sample data. **Use this approach on our pipeline**
#
# 3. Add POS with SpaCY - our data - dictionary: approach used to easily visualize POS tagging on our data set, but won't work on pipeline.

# %% [markdown]
# # Libraries

# %%
# drive
from google.colab import drive
drive.mount('/content/drive')

#pos tagging
import spacy

# standard library
import numpy as np
import pandas as pd
import tensorflow as tf

#removes punctuation for confusion set
import string

#LLM
# !pip install --q transformers
from transformers import RobertaTokenizer, TFRobertaModel, pipeline, TFRobertaForMaskedLM

# progress bar
from tqdm import tqdm
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Add POS with SpaCY - sample data

# %% [markdown]
# ### Create sample data

# %%
#load spacy for English
nlp = spacy.load("en_core_web_sm")

# %%
# crate some sample sentences
org_text = []
org_text.append("They drank the pub .")
org_text.append("I am looking forway to see you soon .")
org_text.append("The cat sat on mat .")
org_text.append('He ate a apple .')
org_text
# Out:
# ['They drank the pub .',
#  'I am looking forway to see you soon .',
#  'The cat sat on mat .',
#  'He ate a apple .']

# %% [markdown]
# ### Create two lists: One for tokenized words, another for POS

# %%
#add POS tagging to tokens as a two lists
sample_pos_sentence = [[token.pos_ for token in nlp(sentence)]
    for sentence in org_text
               ]

print("List of POS:", sample_pos_sentence)

sample_tok_sentence = [[token.text for token in nlp(sentence)]
    for sentence in org_text
                ]
print("List of tokens:", sample_tok_sentence)
# Out:
# List of POS: [['PRON', 'VERB', 'DET', 'NOUN', 'PUNCT'], ['PRON', 'AUX', 'VERB', 'ADJ', 'PART', 'VERB', 'PRON', 'ADV', 'PUNCT'], ['DET', 'NOUN', 'VERB', 'ADP', 'PROPN', 'PUNCT'], ['PRON', 'VERB', 'DET', 'NOUN', 'PUNCT']]
# List of tokens: [['They', 'drank', 'the', 'pub', '.'], ['I', 'am', 'looking', 'forway', 'to', 'see', 'you', 'soon', '.'], ['The', 'cat', 'sat', 'on', 'mat', '.'], ['He', 'ate', 'a', 'apple', '.']]

# %% [markdown]
# ### Mask all words found in the confusion set

# %%
# List of common determiners
det = ['the', 'a', 'an', 'this', 'that', 'these', 'those', 'my', 'your', 'his',
       'her', 'its', 'our', 'their', 'all', 'both', 'half', 'either', 'neither',
       'each', 'every', 'other', 'another', 'such', 'what', 'rather', 'quite']

# List of common prepositions
prep = ["about", "at", "by", "for", "from", "in", "of", "on", "to", "with",
        "into", "during", "including", "until", "against", "among",
        "throughout", "despite", "towards", "upon", "concerning"]

# List of helping verbs
helping_verbs = ['am', 'is', 'are', 'was', 'were', 'being', 'been', 'be',
                 'have', 'has', 'had', 'do', 'does', 'did', 'will', 'would',
                 'shall', 'should', 'may', 'might', 'must', 'can', 'could']

confusion_set = det + prep + helping_verbs

masked_sentences = []

for sentence in sample_tok_sentence:
  masked_words = []

  for word in sentence:
    if word.lower() in confusion_set:
      masked_words.append('<mask>')
    else:
      masked_words.append(word)

  masked_sentences.append(masked_words)

print(masked_sentences)
# Out:
# [['They', 'drank', '<mask>', 'pub', '.'], ['I', '<mask>', 'looking', 'forway', '<mask>', 'see', 'you', 'soon', '.'], ['<mask>', 'cat', 'sat', '<mask>', 'mat', '.'], ['He', 'ate', '<mask>', 'apple', '.']]

# %% [markdown]
# ### Find probabilities for masked words

# %%
# Join back to a single, untokenized sentence:
joined_sentences = []
for sentence in masked_sentences:
    joined = ' '.join(sentence)
    joined_sentences.append(joined)

print(joined_sentences)
# Out:
# ['They drank <mask> pub .', 'I <mask> looking forway <mask> see you soon .', '<mask> cat sat <mask> mat .', 'He ate <mask> apple .']

# %%
# Find masked probabilities
unmasker = pipeline('fill-mask', model='roberta-large')

suggestions = []
for sentence in tqdm(joined_sentences):
    suggestions.append(unmasker(sentence))
# Out:
# 100%|██████████| 4/4 [00:01<00:00,  2.28it/s]

# %%
suggestions
# Out:
# [[{'score': 0.5072934627532959,
#    'token': 5,
#    'token_str': ' the',
#    'sequence': 'They drank the pub.'},
#   {'score': 0.10973586142063141,
#    'token': 11,
#    'token_str': ' in',
#    'sequence': 'They drank in pub.'},
#   {'score': 0.09439131617546082,
#    'token': 10,
#    'token_str': ' a',
#    'sequence': 'They drank a pub.'},
#   {'score': 0.06871365755796432,
#    'token': 23,
#    'token_str': ' at',
#    'sequence': 'They drank at pub.'},
#   {'score': 0.03474224731326103,
#    'token': 8,
#    'token_str': ' and',
#    'sequence': 'They drank and pub.'}],
#  [[{'score': 0.7100566625595093,
#     'token': 524,
#     'token_str': ' am',
#     'sequence': '<s>I am looking forway<mask> see you soon.</s>'},
#    {'score': 0.19876757264137268,
#     'token': 437,
#     'token_str': "'m",
#     'sequence': "<s>I'm looking forway<mask> see you soon.</s>"},
#    {'score': 0.023501884192228317,
#     'token': 21,
#     'token_str': ' was',
#     'sequence': '<s>I was looking forway<mask> see you soon.</s>'},
#    {'score': 0.014689385890960693,
#     'token': 489,
#     'token_str': ' keep',
#     'sequence': '<s>I keep looking forway<mask> see you soon.</s>'},
#    {'score': 0.005450359545648098,
#     'token': 40,
#     'token_str': ' will',
#     'sequence': '<s>I will looking forway<mask> see you soon.</s>'}],
#   [{'score': 0.3623572587966919,
#     'token': 7,
#     'token_str': ' to',
#     'sequence': '<s>I<mask> looking forway to see you soon.</s>'},
#    {'score': 0.252675861120224,
#     'token': 8,
#     'token_str': ' and',
#     'sequence': '<s>I<mask> looking forway and see you soon.</s>'},
#    {'score': 0.04912566766142845,
#     'token': 40,
#     'token_str': ' will',
#     'sequence': '<s>I<mask> looking forway will see you soon.</s>'},
#    {'score': 0.043511804193258286,
#     'token': 2156,
#     'token_str': ',',
#     'sequence': '<s>I<mask> looking forway, see you soon.</s>'},
#    {'score': 0.038218848407268524,
#     'token': 6,
#     'token_str': ',',
#     'sequence': '<s>I<mask> looking forway, see you soon.</s>'}]],
#  [[{'score': 0.3482956290245056,
#     'token': 133,
#     'token_str': 'The',
#     'sequence': '<s>The cat sat<mask> mat.</s>'},
#    {'score': 0.21977292001247406,
#     'token': 250,
#     'token_str': 'A',
#     'sequence': '<s>A cat sat<mask> mat.</s>'},
#    {'score': 0.05037274584174156,
#     'token': 713,
#     'token_str': 'This',
#     'sequence': '<s>This cat sat<mask> mat.</s>'},
#    {'score': 0.04426933825016022,
#     'token': 2387,
#     'token_str': 'My',
#     'sequence': '<s>My cat sat<mask> mat.</s>'},
#    {'score': 0.02750612609088421,
#     'token': 21518,
#     'token_str': 'Another',
#     'sequence': '<s>Another cat sat<mask> mat.</s>'}],
#   [{'score': 0.8306655287742615,
#     'token': 15,
#     'token_str': ' on',
#     'sequence': '<s><mask> cat sat on mat.</s>'},
#    {'score': 0.03657201677560806,
#     'token': 5,
#     'token_str': ' the',
#     'sequence': '<s><mask> cat sat the mat.</s>'},
#    {'score': 0.023689446970820427,
#     'token': 11,
#     'token_str': ' in',
#     'sequence': '<s><mask> cat sat in mat.</s>'},
#    {'score': 0.011341373436152935,
#     'token': 10,
#     'token_str': ' a',
#     'sequence': '<s><mask> cat sat a mat.</s>'},
#    {'score': 0.006330172531306744,
#     'token': 19,
#     'token_str': ' with',
#     'sequence': '<s><mask> cat sat with mat.</s>'}]],
#  [{'score': 0.6995665431022644,
#    'token': 41,
#    'token_str': ' an',
#    'sequence': 'He ate an apple.'},
#   {'score': 0.1730445921421051,
#    'token': 5,
#    'token_str': ' the',
#    'sequence': 'He ate the apple.'},
#   {'score': 0.02855275385081768,
#    'token': 39,
#    'token_str': ' his',
#    'sequence': 'He ate his apple.'},
#   {'score': 0.025053754448890686,
#    'token': 65,
#    'token_str': ' one',
#    'sequence': 'He ate one apple.'},
#   {'score': 0.020147543400526047,
#    'token': 14,
#    'token_str': ' that',
#    'sequence': 'He ate that apple.'}]]

# %%
#add POS tagging to tokens as a two lists
# with this approach, still can't get the masking done

pos_sentence = [[token.pos_ for token in nlp(sentence)]
    for sentence in org_text
]

print("List of POS:", pos_sentence)

tok_sentence = [[token.textfor token in nlp(sentence)]
    for sentence in org_text
]]


print("List of tokens:", tok_sentence)


#clean = [
#    {token.text:token.pos_ for token in nlp(sentence)}
#    for sentence in org_text
#]


# and with this one, some words are removed
#clean = [
#    {token.text:token.pos_ for token in nlp(sentence)}
#    for sentence in org_text
#]
# Out:
# [{'They': 'PRON', 'drank': 'VERB', 'the': 'DET', 'pub': 'NOUN', '.': 'PUNCT'},
#  {'I': 'PRON',
#   'am': 'AUX',
#   'looking': 'VERB',
#   'forway': 'ADJ',
#   'to': 'PART',
#   'see': 'VERB',
#   'you': 'PRON',
#   'soon': 'ADV',
#   '.': 'PUNCT'},
#  {'The': 'DET',
#   'cat': 'NOUN',
#   'sat': 'VERB',
#   'on': 'ADP',
#   'mat': 'PROPN',
#   '.': 'PUNCT'},
#  {'He': 'PRON', 'ate': 'VERB', 'a': 'DET', 'apple': 'NOUN', '.': 'PUNCT'}]

# %%
# Mask the word only if the word is in the confusion set

pos_mask = ['DET', 'VERB', 'ADP']

# List of common determiners
det = ['the', 'a', 'an', 'this', 'that', 'these', 'those', 'my', 'your', 'his',
       'her', 'its', 'our', 'their', 'all', 'both', 'half', 'either', 'neither',
       'each', 'every', 'other', 'another', 'such', 'what', 'rather', 'quite']

# List of common prepositions
prep = ["about", "at", "by", "for", "from", "in", "of", "on", "to", "with",
        "into", "during", "including", "until", "against", "among",
        "throughout", "despite", "towards", "upon", "concerning"]

# List of helping verbs
helping_verbs = ['am', 'is', 'are', 'was', 'were', 'being', 'been', 'be',
                 'have', 'has', 'had', 'do', 'does', 'did', 'will', 'would',
                 'shall', 'should', 'may', 'might', 'must', 'can', 'could']

for d in clean:
    for k, v in d.items():
        if k in list(set(det + prep + helping_verbs)) and v in pos_mask:
            d[k] = '<mask>'

clean
# Out:
# [{'They': 'PRON',
#   'drank': 'VERB',
#   'the': '<mask>',
#   'pub': 'NOUN',
#   '.': 'PUNCT',
#   'DET': '<mask>'},
#  {'I': 'PRON',
#   'am': 'AUX',
#   'looking': 'VERB',
#   'forway': 'ADJ',
#   'to': 'PART',
#   'see': 'VERB',
#   'you': 'PRON',
#   'soon': 'ADV',
#   '.': 'PUNCT'},
#  {'The': 'DET',
#   'cat': 'NOUN',
#   'sat': 'VERB',
#   'on': '<mask>',
#   'mat': 'PROPN',
#   '.': 'PUNCT'},
#  {'He': 'PRON', 'ate': 'VERB', 'a': '<mask>', 'apple': 'NOUN', '.': 'PUNCT'}]

# %%
#convert back to a list of sentences
sentences = []
for d in clean:
  sentence = ' '.join(d.keys())
  sentences.append(sentence)

print(sentences)
# Out:
# ['They drank the pub .', 'I am looking forway to see you soon .', 'The cat sat on mat .', 'He ate a apple .']

# %%
# use a MLM to generate likely options for each of the masked words.
checkpoint = 'roberta-large'
tokenizer = RobertaTokenizer.from_pretrained(checkpoint)
model = TFRobertaForMaskedLM.from_pretrained(checkpoint)
# Out:
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFRobertaForMaskedLM: ['roberta.embeddings.position_ids']
# - This IS expected if you are initializing TFRobertaForMaskedLM from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFRobertaForMaskedLM from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# All the weights of TFRobertaForMaskedLM were initialized from the PyTorch model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFRobertaForMaskedLM for predictions without further training.

# %%
unmasker = pipeline('fill-mask', model='roberta-large')
unmasker('He ate <mask> apple.')
# Out:
# [{'score': 0.44446417689323425,
#   'token': 5,
#   'token_str': ' the',
#   'sequence': 'He ate the apple.'},
#  {'score': 0.31382378935813904,
#   'token': 41,
#   'token_str': ' an',
#   'sequence': 'He ate an apple.'},
#  {'score': 0.12721681594848633,
#   'token': 39,
#   'token_str': ' his',
#   'sequence': 'He ate his apple.'},
#  {'score': 0.04988005757331848,
#   'token': 277,
#   'token_str': ' another',
#   'sequence': 'He ate another apple.'},
#  {'score': 0.030983757227659225,
#   'token': 65,
#   'token_str': ' one',
#   'sequence': 'He ate one apple.'}]

# %%
sentences
# Out:
# ['They drank <mask> pub .',
#  'you am see forway to soon .',
#  'The cat sat <mask> mat .',
#  'Giant predator is <mask> .',
#  'There brought <mask> age . has many <mask>',
#  'He ate <mask> apple .']

# %% [markdown]
# # Add POS for confusion set
#
# **Determiners:**
#
# - Articles: a, an, the
# - Demonstratives: this, that, these, those
# - Possessives: my, your, his, her, its, our, their
# - Quantifiers: some, many, much, few, several, each, every, either, neither
# - Numbers: one, two, first, second, etc.
# - Interrogatives: which, what

# %%
# List of common determiners: PRON - Pronoun # NOUN - Noun # ADV - Adverb # CCONJ - Coordinating Conjunction # ADJ - Adjective
det = ['the', 'a', 'an', 'this', 'that', 'these', 'those', 'my', 'your', 'his',
       'her', 'its', 'our', 'their', 'all', 'both', 'half', 'either', 'neither',
       'each', 'every', 'other', 'another', 'such', 'what', 'rather', 'quite']

# List of common prepositions and adverbs
prep = ["about", "at", "by", "for", "from", "in", "of", "on", "to", "with",
        "into", "during", "including", "until", "against", "among",
        "throughout", "despite", "towards", "upon", "concerning"]

# List of helping verbs and some verbs (9:14 are verbs - 'have', 'has', 'had', 'do', 'does', 'did')
#helping_verbs = ['am', 'is', 'are', 'was', 'were', 'being', 'been', 'be',
#                 'have', 'has', 'had', 'do', 'does', 'did', 'will', 'would',
3                 'shall', 'should', 'may', 'might', 'must', 'can', 'could']


helping_verbs = ['am', 'is', 'are', 'was', 'were', 'being', 'been', 'be',
                 'will', 'would','shall', 'should', 'may', 'might', 'must', 'can', 'could']

# %%
# check to see if POS changes based on context

expect_verb = "I have a cat"
expect_aux = "I have been planning on getting a cat"

expect_verb_pos = [token.pos_ for token in nlp(expect_verb)]
print(expect_verb_pos)

expect_aux_pos = [token.pos_ for token in nlp(expect_aux)]
print(expect_aux_pos)
# Out:
# ['PRON', 'VERB', 'DET', 'NOUN']
# ['PRON', 'AUX', 'AUX', 'VERB', 'ADP', 'VERB', 'DET', 'NOUN']

# %% [markdown]
# ### "Determiners"

# %%
det_pos = [[token.pos_ for token in nlp(sentence)]
    for sentence in det
]

det_pos
# Out:
# [['PRON'],
#  ['PRON'],
#  ['PRON'],
#  ['PRON'],
#  ['PRON'],
#  ['PRON'],
#  ['PRON'],
#  ['PRON'],
#  ['PRON'],
#  ['PRON'],
#  ['PRON'],
#  ['PRON'],
#  ['PRON'],
#  ['PRON'],
#  ['PRON'],
#  ['PRON'],
#  ['NOUN'],
#  ['ADV'],
#  ['CCONJ'],
#  ['PRON'],
#  ['PRON'],
#  ['ADJ'],
#  ['PRON'],
#  ['ADJ'],
#  ['PRON'],
#  ['ADV'],
#  ['ADV']]

# %% [markdown]
# ### "Prepositions"

# %%
# ADV - Adverb
# ADP - Adposition
# PART - Particle
# VERB - Verb
# SCONJ - Subordinating Conjunction

prep_pos = [[token.pos_ for token in nlp(sentence)]
    for sentence in prep
]

prep_pos
# Out:
# [['ADV'],
#  ['ADP'],
#  ['ADP'],
#  ['ADP'],
#  ['ADP'],
#  ['ADP'],
#  ['ADP'],
#  ['ADP'],
#  ['PART'],
#  ['ADP'],
#  ['ADP'],
#  ['ADP'],
#  ['VERB'],
#  ['ADP'],
#  ['ADP'],
#  ['ADP'],
#  ['ADP'],
#  ['SCONJ'],
#  ['ADP'],
#  ['SCONJ'],
#  ['VERB']]

# %% [markdown]
# ### "Auxiliary verbs"

# %%
helping_verbs_pos = [[token.pos_ for token in nlp(sentence)]
    for sentence in helping_verbs
]

helping_verbs_pos
# Out:
# [['AUX'],
#  ['AUX'],
#  ['AUX'],
#  ['AUX'],
#  ['AUX'],
#  ['AUX'],
#  ['AUX'],
#  ['AUX'],
#  ['VERB'],
#  ['VERB'],
#  ['VERB'],
#  ['VERB'],
#  ['VERB'],
#  ['VERB'],
#  ['AUX'],
#  ['AUX'],
#  ['AUX'],
#  ['AUX'],
#  ['AUX'],
#  ['AUX'],
#  ['AUX'],
#  ['AUX'],
#  ['AUX']]

# %% [markdown]
# # Add POS with SpaCY - our data - 2 lists

# %% [markdown]
# ### Load our data

# %%
df = pd.read_csv('/content/drive/MyDrive/266/Data/Clean_Data/EmoV_Arctic/punctuated_cased_train.csv')
df.head()
# Out:
#    Unnamed: 0                 filename clean_filename actor  gender emotion  \
# 0           0    amused_29-45_0042.wav             42   bea  female  amused
# 1           1    amused_46-56_0046.wav             46   bea  female  amused
# 2           2     amused_1-15_0005.wav              5   bea  female  amused
# 3           3  amused_281-308_0281.wav            281   bea  female  amused
# 4           4  amused_225-252_0226.wav            226   bea  female  amused
#
#                                   auto_transcription  \
# 0  HOW COULD HE EXPLAIN HIS POSSESSION OF THE SKETCH
# 1  THE GIRL FACED HIM HER EYES SHINING WITH SUDDE...
# 2                             WILL WE EVER FORGET IT
# 3      I DO NOT BLAME YOU FOR ANYTHING REMEMBER THAT
# 4                         THAT CAME BEFORE MY A V CS
#
#                                                label  \
# 0  How could he explain his possession of the ske...
# 1  The girl faced him, her eyes shining with sudd...
# 2                            Will we ever forget it.
# 3    I do not blame you for anything; remember that.
# 4                       That came before my A B C's.
#
#                           cleaned_auto_transcription  \
# 0  How could he explain his possession of the ske...
# 1  The girl faced him, her eyes shining with sudd...
# 2                            Will we ever forget it.
# 3    I do not blame you for anything. Remember that.
# 4                        That came before my a v cs.
#
#                                        cleaned_label
# 0  How could he explain his possession of the ske...
# 1  The girl faced him, her eyes shining with sudd...
# 2                            Will we ever forget it.
# 3    I do not blame you for anything. Remember that.
# 4                       That came before my A B C's.

# %% [markdown]
# ### Create two lists: one with tokenized sentences, another with POS

# %%
# convert series to list
check = df['cleaned_auto_transcription'].tolist()

# add a space before each punctuation mark to allow for proper POS tagging
punctuated_sentences = []
for sentence in check:
    punctuated = sentence.translate(str.maketrans({key:" {0} ".format(key) for key in string.punctuation}))
    punctuated_sentences.append(punctuated)

punctuated_sentences[:3]
# Out:
# ['How could he explain his possession of the sketch . ',
#  'The girl faced him ,  her eyes shining with sudden fear . ',
#  'Will we ever forget it . ']

# %%
type(punctuated_sentences)
# Out:
# list

# %%
pos_sentence = [[token.pos_ for token in nlp(sentence)]
    for sentence in punctuated_sentences
               ]
print("List of POS:", pos_sentence)

tok_sentence = [[token.text for token in nlp(sentence)]
    for sentence in punctuated_sentences
                ]
print("List of tokens:", tok_sentence)
# Out:
# List of POS: [['SCONJ', 'AUX', 'PRON', 'VERB', 'PRON', 'NOUN', 'ADP', 'DET', 'NOUN', 'PUNCT'], ['DET', 'NOUN', 'VERB', 'PRON', 'PUNCT', 'SPACE', 'PRON', 'NOUN', 'VERB', 'ADP', 'ADJ', 'NOUN', 'PUNCT'], ['AUX', 'PRON', 'ADV', 'VERB', 'PRON', 'PUNCT'], ['PRON', 'AUX', 'PART', 'VERB', 'PRON', 'ADP', 'PRON', 'PUNCT', 'SPACE', 'VERB', 'PRON', 'PUNCT'], ['PRON', 'VERB', 'ADP', 'PRON', 'DET', 'NOUN', 'NOUN', 'PUNCT'], ['ADV', 'ADV', 'PUNCT', 'SPACE', 'PRON', 'AUX', 'ADJ', 'PUNCT', 'SPACE', 'PRON', 'VERB', 'PUNCT'], ['PRON', 'VERB', 'ADP', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', 'CCONJ', 'VERB', 'VERB', 'PRON', 'PUNCT'], ['AUX', 'VERB', 'NOUN', 'VERB', 'DET', 'NOUN', 'PUNCT'], ['ADV', 'ADV', 'PUNCT', 'SPACE', 'DET', 'NOUN', 'AUX', 'ADV', 'VERB', 'ADP', 'NOUN', 'PUNCT'], ['PROPN', 'PUNCT', 'SPACE', 'PRON', 'NOUN', 'PUNCT', 'SPACE', 'PRON', 'VERB', 'PART', 'VERB', 'ADJ', 'NOUN', 'ADP', 'PRON', 'NOUN', 'PUNCT'], ['PRON', 'NOUN', 'AUX', 'ADV', 'ADJ', 'PUNCT'], ['PROPN', 'NOUN', 'ADP', 'NOUN', 'PUNCT', 'SPACE', 'ADV', 'ADP', 'ADP', 'NOUN', 'ADP', 'PRON', 'ADV', 'PUNCT'], ['DET', 'VERB', 'NOUN', 'VERB', 'ADP', 'PRON', 'NOUN', 'PUNCT'], ['DET', 'NOUN', 'AUX', 'AUX', 'VERB', 'ADV', 'ADP', 'PRON', 'NOUN', 'PUNCT'], ['PRON', 'AUX', 'ADJ', 'NOUN', 'CCONJ', 'VERB', 'NOUN', 'ADP', 'NOUN', 'PUNCT'], ['PRON', 'ADJ', 'NOUN', 'AUX', 'VERB', 'PUNCT'], ['ADP', 'DET', 'NOUN', 'PUNCT', 'SPACE', 'PRON', 'VERB', 'PUNCT', 'SPACE', 'ADP', 'DET', 'NOUN', 'DET', 'ADJ', 'NOUN', 'ADP', 'PROPN', 'PUNCT'], ['PRON', 'AUX', 'ADV', 'VERB', 'PRON', 'SCONJ', 'PRON', 'VERB', 'DET', 'NOUN', 'ADP', 'ADP', 'NOUN', 'PUNCT'], ['CCONJ', 'PRON', 'PRON', 'VERB', 'ADP', 'PRON', 'NOUN', 'NOUN', 'ADJ', 'SCONJ', 'PRON', 'AUX', 'VERB', 'PUNCT'], ['PRON', 'VERB', 'PUNCT', 'NOUN', 'AUX', 'VERB', 'DET', 'NOUN', 'NOUN', 'ADP', 'DET', 'PROPN', 'PUNCT'], ['PROPN', 'VERB', 'PUNCT', 'SPACE', 'PROPN', 'ADP', 'NOUN', 'PUNCT'], ['DET', 'NOUN', 'ADP', 'ADJ', 'NOUN', 'PUNCT', 'SPACE', 'ADV', 'VERB', 'PUNCT', 'SPACE', 'CCONJ', 'NOUN', 'ADP', 'DET', 'ADJ', 'NOUN', 'PUNCT'], ['ADV', 'PRON', 'VERB', 'ADV', 'ADP', 'DET', 'ADJ', 'NOUN', 'ADP', 'NOUN', 'PUNCT'], ['PROPN', 'AUX', 'VERB', 'DET', 'NOUN', 'NOUN', 'PUNCT'], ['NOUN', 'ADP', 'ADV', 'NOUN', 'PUNCT', 'SPACE', 'PROPN', 'PUNCT', 'PROPN', 'VERB', 'ADP', 'NOUN', 'CCONJ', 'NOUN', 'PUNCT'], ['PRON', 'AUX', 'VERB', 'NOUN', 'NOUN', 'PUNCT', 'SPACE', 'PRON', 'PRON', 'AUX', 'PUNCT'], ['ADV', 'PUNCT', 'SPACE', 'PRON', 'VERB', 'PRON', 'PUNCT', 'SPACE', 'CCONJ', 'PRON', 'VERB', 'INTJ', 'NUM', 'ADJ', 'NOUN', 'PUNCT'], ['ADP', 'DET', 'ADJ', 'NOUN', 'PUNCT', 'SPACE', 'PRON', 'VERB', 'CCONJ', 'VERB', 'PUNCT'], ['DET', 'NOUN', 'NOUN', 'VERB', 'ADV', 'PUNCT'], ['PRON', 'VERB', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', 'PRON', 'AUX', 'VERB', 'ADP', 'PRON', 'PUNCT'], ['NUM', 'NOUN', 'ADV', 'PUNCT', 'SPACE', 'PROPN', 'VERB', 'SCONJ', 'PRON', 'NOUN', 'PART', 'PART', 'NOUN', 'AUX', 'VERB', 'PUNCT'], ['CCONJ', 'PRON', 'VERB', 'DET', 'NOUN', 'ADP', 'VERB', 'PRON', 'ADJ', 'NOUN', 'PUNCT'], ['PRON', 'AUX', 'PART', 'VERB', 'PRON', 'NOUN', 'ADP', 'NOUN', 'NOUN', 'PUNCT'], ['DET', 'NOUN', 'NOUN', 'VERB', 'PRON', 'NOUN', 'NOUN', 'ADP', 'PRON', 'PUNCT'], ['DET', 'ADJ', 'NOUN', 'ADP', 'VERB', 'NOUN', 'VERB', 'PROPN', 'DET', 'ADJ', 'NOUN', 'PUNCT', 'SPACE', 'NOUN', 'PUNCT'], ['CCONJ', 'SCONJ', 'PRON', 'VERB', 'ADV', 'ADP', 'DET', 'ADJ', 'NOUN', 'PUNCT', 'SPACE', 'VERB', 'PRON', 'ADJ', 'PUNCT'], ['PRON', 'AUX', 'DET', 'NOUN', 'ADP', 'PRON', 'ADJ', 'NOUN', 'PUNCT'], ['PRON', 'AUX', 'VERB', 'PART', 'VERB', 'NOUN', 'PUNCT', 'SPACE', 'CCONJ', 'PRON', 'AUX', 'VERB', 'ADP', 'NOUN', 'PUNCT'], ['PRON', 'VERB', 'PUNCT', 'NOUN', 'VERB', 'SCONJ', 'PRON', 'PUNCT', 'ADP', 'ADV', 'ADV', 'ADV', 'PUNCT'], ['PRON', 'VERB', 'ADP', 'PRON', 'ADP', 'DET', 'PROPN', 'PROPN', 'ADP', 'PROPN', 'NUM', 'NOUN', 'PUNCT'], ['VERB', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', 'NOUN', 'VERB', 'NOUN', 'PUNCT'], ['PRON', 'AUX', 'VERB', 'PRON', 'ADV', 'PUNCT'], ['PRON', 'AUX', 'ADV', 'ADJ', 'ADP', 'PRON', 'NOUN', 'ADP', 'ADV', 'ADJ ...
# List of tokens: [['How', 'could', 'he', 'explain', 'his', 'possession', 'of', 'the', 'sketch', '.'], ['The', 'girl', 'faced', 'him', ',', ' ', 'her', 'eyes', 'shining', 'with', 'sudden', 'fear', '.'], ['Will', 'we', 'ever', 'forget', 'it', '.'], ['I', 'do', 'not', 'blame', 'you', 'for', 'anything', '.', ' ', 'Remember', 'that', '.'], ['That', 'came', 'before', 'my', 'a', 'v', 'cs', '.'], ['Of', 'course', ',', ' ', 'that', 'is', 'uninteresting', '.', ' ', 'She', 'continued', '.'], ['He', 'wated', 'in', 'the', 'edge', 'of', 'the', 'water', 'and', 'began', 'scrubbing', 'himself', '.'], ['Could', 'almay', 'dreams', 'violated', 'this', 'law', '.'], ['Down', 'there', ',', ' ', 'the', 'earth', 'was', 'already', 'swelling', 'with', 'life', '.'], ['Nunte', ',', ' ', 'my', 'surprise', ',', ' ', 'he', 'began', 'to', 'show', 'actual', 'enthusiasm', 'in', 'my', 'favor', '.'], ['His', 'voice', 'was', 'passionately', 'rebellious', '.'], ['Ahai', 'game', 'for', 'information', ',', ' ', 'more', 'out', 'of', 'curiosity', 'than', 'anything', 'else', '.'], ['A', 'maddening', 'joy', 'pounded', 'in', 'his', 'brain', '.'], ['The', 'questions', 'may', 'have', 'come', 'vaguely', 'in', 'his', 'mind', '.'], ['They', 'are', 'big', 'trees', 'and', 'require', 'plenty', 'of', 'room', '.'], ['His', 'immaculate', 'appearance', 'was', 'gone', '.'], ['In', 'the', 'picture', '.', ' ', 'He', 'saw', ',', ' ', 'at', 'each', 'moment', 'a', 'greater', 'resemblance', 'to', 'jean', '.'], ['He', 'had', 'barely', 'entered', 'this', 'when', 'he', 'saw', 'the', 'glow', 'of', 'of', 'fire', '.'], ['But', 'what', 'they', 'want', 'with', 'your', 'tooth', 'brushes', 'more', 'than', 'i', 'can', 'imagine', '.'], ['They', 'wouldn', "'", 't', 'be', 'sweeping', 'an', 'pig', 'vessel', 'like', 'the', 'martha', '.'], ['Much', 'replied', '.', ' ', 'Jean', 'as', 'tersley', '.'], ['A', 'combination', 'of', 'canadian', 'capital', ',', ' ', 'quickly', 'organized', ',', ' ', 'and', 'petition', 'for', 'the', 'same', 'privileges', '.'], ['Then', 'he', 'stepped', 'back', 'with', 'a', 'low', 'cry', 'of', 'pleasure', '.'], ['Gean', 'was', 'turning', 'the', 'bow', 'shoreward', '.'], ['Men', 'of', 'seldom', 'stamp', ',', ' ', 'don', "'", 't', 'stop', 'at', 'women', 'and', 'children', '.'], ['They', 'are', 'cuffing', 'ors', 'ore', ',', ' ', 'whoever', 'they', 'are', '.'], ['Instead', ',', ' ', 'he', 'joined', 'her', ',', ' ', 'and', 'they', 'ate', 'like', 'two', 'hungry', 'children', '.'], ['For', 'a', 'full', 'minute', ',', ' ', 'he', 'crouched', 'and', 'listened', '.'], ['The', 'singing', 'voice', 'approached', 'rapidly', '.'], ['He', 'had', 'no', 'excuse', 'for', 'the', 'feelings', 'which', 'were', 'aroused', 'in', 'him', '.'], ['Two', 'days', 'ago', ',', ' ', 'jean', 'learned', 'where', 'her', 'father', "'", 's', 'men', 'were', 'hiding', '.'], ['But', 'they', 'make', 'the', 'mistake', 'of', 'ignoring', 'their', 'own', 'duality', '.'], ['They', 'are', 'to', 'attack', 'your', 'camp', 'to', 'morrow', 'night', '.'], ['The', 'wolf', 'dog', 'thrust', 'his', 'gaunt', 'muzzle', 'toward', 'him', '.'], ['This', 'tacit', 'promise', 'of', 'continued', 'acquaintance', 'gave', 'saxon', 'a', 'little', 'joy', ',', ' ', 'thrill', '.'], ['And', 'when', 'you', 'come', 'back', 'in', 'a', 'few', 'days', ',', ' ', 'bring', 'i', 'lean', '.'], ['What', 'was', 'the', 'object', 'of', 'your', 'little', 'sensation', '.'], ['I', 'am', 'going', 'to', 'surprise', 'father', ',', ' ', 'and', 'you', 'will', 'go', 'with', 'pierre', '.'], ['I', 'don', "'", 't', 'know', 'why', 'you', "'", 're', 'here', 'at', 'all', '.'], ['It', 'happened', 'to', 'him', 'at', 'the', 'gayina', 'society', 'in', 'oakland', 'one', 'afternoon', '.'], ['See', 'the', 'length', 'of', 'the', 'body', 'tat', 'youlongated', 'neck', '.'], ['He', 'will', 'follow', 'us', 'soon', '.'], ['He', 'was', 'ahead', 'shorter', 'than', 'his', 'companion', 'of', 'almost', 'delicate', 'physique', '.'], ['Ahead', 'of', 'them', ',', ' ', 'they', 'saw', 'a', 'glimmer', 'of', 'su ...

# %% [markdown]
# ### Mask all words found in the confusion set

# %%
# List of common determiners
det = ['the', 'a', 'an', 'this', 'that', 'these', 'those', 'my', 'your', 'his',
       'her', 'its', 'our', 'their', 'all', 'both', 'half', 'either', 'neither',
       'each', 'every', 'other', 'another', 'such', 'what', 'rather', 'quite']

# List of common prepositions
prep = ["about", "at", "by", "for", "from", "in", "of", "on", "to", "with",
        "into", "during", "including", "until", "against", "among",
        "throughout", "despite", "towards", "upon", "concerning"]

# List of helping verbs
helping_verbs = ['am', 'is', 'are', 'was', 'were', 'being', 'been', 'be',
                 'have', 'has', 'had', 'do', 'does', 'did', 'will', 'would',
                 'shall', 'should', 'may', 'might', 'must', 'can', 'could']

confusion_set = det + prep + helping_verbs

masked_sentences = []

for sentence in tok_sentence:
  masked_words = []

  for word in sentence:
    if word.lower() in confusion_set:
      masked_words.append('<mask>')
    else:
      masked_words.append(word)

  masked_sentences.append(masked_words)

print(masked_sentences)
# Out:
# [['How', '<mask>', 'he', 'explain', '<mask>', 'possession', '<mask>', '<mask>', 'sketch', '.'], ['<mask>', 'girl', 'faced', 'him', ',', ' ', '<mask>', 'eyes', 'shining', '<mask>', 'sudden', 'fear', '.'], ['<mask>', 'we', 'ever', 'forget', 'it', '.'], ['I', '<mask>', 'not', 'blame', 'you', '<mask>', 'anything', '.', ' ', 'Remember', '<mask>', '.'], ['<mask>', 'came', 'before', '<mask>', '<mask>', 'v', 'cs', '.'], ['<mask>', 'course', ',', ' ', '<mask>', '<mask>', 'uninteresting', '.', ' ', 'She', 'continued', '.'], ['He', 'wated', '<mask>', '<mask>', 'edge', '<mask>', '<mask>', 'water', 'and', 'began', 'scrubbing', 'himself', '.'], ['<mask>', 'almay', 'dreams', 'violated', '<mask>', 'law', '.'], ['Down', 'there', ',', ' ', '<mask>', 'earth', '<mask>', 'already', 'swelling', '<mask>', 'life', '.'], ['Nunte', ',', ' ', '<mask>', 'surprise', ',', ' ', 'he', 'began', '<mask>', 'show', 'actual', 'enthusiasm', '<mask>', '<mask>', 'favor', '.'], ['<mask>', 'voice', '<mask>', 'passionately', 'rebellious', '.'], ['Ahai', 'game', '<mask>', 'information', ',', ' ', 'more', 'out', '<mask>', 'curiosity', 'than', 'anything', 'else', '.'], ['<mask>', 'maddening', 'joy', 'pounded', '<mask>', '<mask>', 'brain', '.'], ['<mask>', 'questions', '<mask>', '<mask>', 'come', 'vaguely', '<mask>', '<mask>', 'mind', '.'], ['They', '<mask>', 'big', 'trees', 'and', 'require', 'plenty', '<mask>', 'room', '.'], ['<mask>', 'immaculate', 'appearance', '<mask>', 'gone', '.'], ['<mask>', '<mask>', 'picture', '.', ' ', 'He', 'saw', ',', ' ', '<mask>', '<mask>', 'moment', '<mask>', 'greater', 'resemblance', '<mask>', 'jean', '.'], ['He', '<mask>', 'barely', 'entered', '<mask>', 'when', 'he', 'saw', '<mask>', 'glow', '<mask>', '<mask>', 'fire', '.'], ['But', '<mask>', 'they', 'want', '<mask>', '<mask>', 'tooth', 'brushes', 'more', 'than', 'i', '<mask>', 'imagine', '.'], ['They', 'wouldn', "'", 't', '<mask>', 'sweeping', '<mask>', 'pig', 'vessel', 'like', '<mask>', 'martha', '.'], ['Much', 'replied', '.', ' ', 'Jean', 'as', 'tersley', '.'], ['<mask>', 'combination', '<mask>', 'canadian', 'capital', ',', ' ', 'quickly', 'organized', ',', ' ', 'and', 'petition', '<mask>', '<mask>', 'same', 'privileges', '.'], ['Then', 'he', 'stepped', 'back', '<mask>', '<mask>', 'low', 'cry', '<mask>', 'pleasure', '.'], ['Gean', '<mask>', 'turning', '<mask>', 'bow', 'shoreward', '.'], ['Men', '<mask>', 'seldom', 'stamp', ',', ' ', 'don', "'", 't', 'stop', '<mask>', 'women', 'and', 'children', '.'], ['They', '<mask>', 'cuffing', 'ors', 'ore', ',', ' ', 'whoever', 'they', '<mask>', '.'], ['Instead', ',', ' ', 'he', 'joined', '<mask>', ',', ' ', 'and', 'they', 'ate', 'like', 'two', 'hungry', 'children', '.'], ['<mask>', '<mask>', 'full', 'minute', ',', ' ', 'he', 'crouched', 'and', 'listened', '.'], ['<mask>', 'singing', 'voice', 'approached', 'rapidly', '.'], ['He', '<mask>', 'no', 'excuse', '<mask>', '<mask>', 'feelings', 'which', '<mask>', 'aroused', '<mask>', 'him', '.'], ['Two', 'days', 'ago', ',', ' ', 'jean', 'learned', 'where', '<mask>', 'father', "'", 's', 'men', '<mask>', 'hiding', '.'], ['But', 'they', 'make', '<mask>', 'mistake', '<mask>', 'ignoring', '<mask>', 'own', 'duality', '.'], ['They', '<mask>', '<mask>', 'attack', '<mask>', 'camp', '<mask>', 'morrow', 'night', '.'], ['<mask>', 'wolf', 'dog', 'thrust', '<mask>', 'gaunt', 'muzzle', 'toward', 'him', '.'], ['<mask>', 'tacit', 'promise', '<mask>', 'continued', 'acquaintance', 'gave', 'saxon', '<mask>', 'little', 'joy', ',', ' ', 'thrill', '.'], ['And', 'when', 'you', 'come', 'back', '<mask>', '<mask>', 'few', 'days', ',', ' ', 'bring', 'i', 'lean', '.'], ['<mask>', '<mask>', '<mask>', 'object', '<mask>', '<mask>', 'little', 'sensation', '.'], ['I', '<mask>', 'going', '<mask>', 'surprise', 'father', ',', ' ', 'and', 'you', '<mask>', 'go', '<mask>', 'pierre', '.'], ['I', 'don', "'", 't', 'know', 'why', 'you', "'", 're', 'here', '<mask>', '<mask>', '.'], ['It', 'happened', '<mask>', 'him', '<mask>', '<mask>', 'gayina', 'soci ...

# %% [markdown]
# ### Find probabilities for masked words

# %%
# Join back to a single, untokenized sentence:
joined_sentences = []
for sentence in masked_sentences:
    joined = ' '.join(sentence)
    joined_sentences.append(joined)

print(joined_sentences)
# Out:
# ['How <mask> he explain <mask> possession <mask> <mask> sketch .', '<mask> girl faced him ,   <mask> eyes shining <mask> sudden fear .', '<mask> we ever forget it .', 'I <mask> not blame you <mask> anything .   Remember <mask> .', '<mask> came before <mask> <mask> v cs .', '<mask> course ,   <mask> <mask> uninteresting .   She continued .', 'He wated <mask> <mask> edge <mask> <mask> water and began scrubbing himself .', '<mask> almay dreams violated <mask> law .', 'Down there ,   <mask> earth <mask> already swelling <mask> life .', 'Nunte ,   <mask> surprise ,   he began <mask> show actual enthusiasm <mask> <mask> favor .', '<mask> voice <mask> passionately rebellious .', 'Ahai game <mask> information ,   more out <mask> curiosity than anything else .', '<mask> maddening joy pounded <mask> <mask> brain .', '<mask> questions <mask> <mask> come vaguely <mask> <mask> mind .', 'They <mask> big trees and require plenty <mask> room .', '<mask> immaculate appearance <mask> gone .', '<mask> <mask> picture .   He saw ,   <mask> <mask> moment <mask> greater resemblance <mask> jean .', 'He <mask> barely entered <mask> when he saw <mask> glow <mask> <mask> fire .', 'But <mask> they want <mask> <mask> tooth brushes more than i <mask> imagine .', "They wouldn ' t <mask> sweeping <mask> pig vessel like <mask> martha .", 'Much replied .   Jean as tersley .', '<mask> combination <mask> canadian capital ,   quickly organized ,   and petition <mask> <mask> same privileges .', 'Then he stepped back <mask> <mask> low cry <mask> pleasure .', 'Gean <mask> turning <mask> bow shoreward .', "Men <mask> seldom stamp ,   don ' t stop <mask> women and children .", 'They <mask> cuffing ors ore ,   whoever they <mask> .', 'Instead ,   he joined <mask> ,   and they ate like two hungry children .', '<mask> <mask> full minute ,   he crouched and listened .', '<mask> singing voice approached rapidly .', 'He <mask> no excuse <mask> <mask> feelings which <mask> aroused <mask> him .', "Two days ago ,   jean learned where <mask> father ' s men <mask> hiding .", 'But they make <mask> mistake <mask> ignoring <mask> own duality .', 'They <mask> <mask> attack <mask> camp <mask> morrow night .', '<mask> wolf dog thrust <mask> gaunt muzzle toward him .', '<mask> tacit promise <mask> continued acquaintance gave saxon <mask> little joy ,   thrill .', 'And when you come back <mask> <mask> few days ,   bring i lean .', '<mask> <mask> <mask> object <mask> <mask> little sensation .', 'I <mask> going <mask> surprise father ,   and you <mask> go <mask> pierre .', "I don ' t know why you ' re here <mask> <mask> .", 'It happened <mask> him <mask> <mask> gayina society <mask> oakland one afternoon .', 'See <mask> length <mask> <mask> body tat youlongated neck .', 'He <mask> follow us soon .', 'He <mask> ahead shorter than <mask> companion <mask> almost delicate physique .', 'Ahead <mask> them ,   they saw <mask> glimmer <mask> sunshine .', "Don ' t you see .   I ' m chewing <mask> thing <mask> too .", 'But there came no promise <mask> <mask> bow <mask> <mask> canoe .', 'Suddenly ,   <mask> finger closed tightly over <mask> handkerchief .', "I ' ll <mask> out <mask> <mask> head <mask> fifteen minutes .", 'They <mask> no idea ,   replied philip .', 'They <mask> <mask> presage <mask> storm .', 'I <mask> <mask> doubly baptized .', 'She said <mask> chattering teeth .', 'He <mask> <mask> lived <mask> found <mask> family <mask> <mask> potino .', 'Fresh gazes ,   till able <mask> walk ,   they clustered <mask> <mask> spokesman .', 'Soaked <mask> sea water ,   they offset <mask> heat rays .', 'It seemed nearer <mask> him since he <mask> seen and talked <mask> gregson .', 'Aha ha ha .   She turned <mask> <mask> <mask> hotel .', "<mask> promoter ' s eyes <mask> heavy <mask> little puffy bags under them .", 'He cried and swung <mask> club wildly .', "I never allow <mask> <mask> ' t <mask> changed <mask> annoy me .", 'He <mask> <mask> foiled <mask> <mask> attempts <mask> escape .', 'I saw it wh ...

# %%
# Find masked probabilities
unmasker = pipeline('fill-mask', model='roberta-large')

suggestions = []

for sentence in tqdm(joined_sentences):
  if "<mask>" in sentence:
    suggestion = unmasker(sentence)
    suggestions.append(suggestion)
  else:
    suggestions.append("No word from sentence found in confusion set.")
    suggestions.append(sentence)

print(suggestions)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
suggestions

# %% [markdown]
# # Add POS with SpaCY - our data - dictionary

# %%
our_data = df['cleaned_auto_transcription']
our_data
# Out:
# 0       How could he explain his possession of the ske...
# 1       The girl faced him, her eyes shining with sudd...
# 2                                 Will we ever forget it.
# 3         I do not blame you for anything. Remember that.
# 4                             That came before my a v cs.
#                               ...
# 9009    Unconsciously, our yells and exclamations yiel...
# 9010        The stout wood was crushed like an egg shell.
# 9011    Ten minutes had not elapsed since he had dropp...
# 9012    I suppose you picked that lingo up among the i...
# 9013    Mc coy found a stifling, poisonous atmosphere ...
# Name: cleaned_auto_transcription, Length: 9014, dtype: object

# %%
df['cln_autot_pos'] = [
    {token.text: token.pos_ for token in nlp(sentence)}
    for sentence in df['cleaned_auto_transcription']
]

# %% [markdown]
# # Some examples of how misspelled words are being tagged
#
# - "Wated" (waited) is correctly recognized as a verb
# - "Nunte" (to) is correctly recognized as a preposition
# - "Gean" (Jeanne)  is correctly recognized as a proper noun
#
#
# - But words that are pasted together in the autotranscpription of course are incorrectly tagged: 'almay': 'VERB', when the original label was ALL MY.
#
#
#
# |autotranscription|pos tagging|
# |---|---|
# |That came before my a v cs.	|{'That': 'PRON', 'came': 'VERB', 'before': 'ADP', 'my': 'PRON', 'a': 'DET', 'v': 'NOUN', 'cs': 'NOUN', '.': 'PUNCT'}|
# |He wated in the edge of the water and began scrubbing himself.|{'He': 'PRON', 'wated': 'VERB', 'in': 'ADP', 'the': 'DET', 'edge': 'NOUN', 'of': 'ADP', 'water': 'NOUN', 'and': 'CCONJ', 'began': 'VERB', 'scrubbing': 'VERB', 'himself': 'PRON', '.': 'PUNCT'}|
# |Nunte, my surprise, he began to show actual enthusiasm in my favor.|{'Nunte': 'PROPN', ',': 'PUNCT', 'my': 'PRON', 'surprise': 'NOUN', 'he': 'PRON', 'began': 'VERB', 'to': 'PART', 'show': 'VERB', 'actual': 'ADJ', 'enthusiasm': 'NOUN', 'in': 'ADP', 'favor': 'NOUN', '.': 'PUNCT'}|
# |Could almay dreams violated this law.|{'Could': 'AUX', 'almay': 'VERB', 'dreams': 'NOUN', 'violated': 'VERB', 'this': 'DET', 'law': 'NOUN', '.': 'PUNCT'}|
